# %%
import numpy as np
from scipy.interpolate import Rbf, InterpolatedUnivariateSpline
import matplotlib.pyplot as plt

# %%
x = [0,0.1,2,4,6,7.9,8]
y = [0,0.5,3,5,2,0.5,0]
xi = np.linspace(0, 10, 101)

# %%
ius = InterpolatedUnivariateSpline(x, y)
rbf = Rbf(x, y)
yi = ius(xi)
fi = rbf(xi)

# %%
plt.plot(x, y, 'bo')
plt.plot(xi, yi, 'g')
plt.plot(xi, fi, 'r')
plt.title('Interpolation using univariate spline')
plt.xlim([-1, 9])
plt.ylim([-2,8])
plt.gca().set_aspect('equal','box')
plt.show()

# %%
yi
# Out:
# array([-4.32123949e-17,  5.00000000e-01,  9.36307359e-01,  1.31339717e+00,
#         1.63574451e+00,  1.90782449e+00,  2.13411217e+00,  2.31908267e+00,
#         2.46721106e+00,  2.58297243e+00,  2.67084188e+00,  2.73529449e+00,
#         2.78080535e+00,  2.81184955e+00,  2.83290218e+00,  2.84843833e+00,
#         2.86293309e+00,  2.88086155e+00,  2.90669879e+00,  2.94491991e+00,
#         3.00000000e+00,  3.07522244e+00,  3.16910380e+00,  3.27896897e+00,
#         3.40214281e+00,  3.53595020e+00,  3.67771600e+00,  3.82476510e+00,
#         3.97442236e+00,  4.12401266e+00,  4.27086086e+00,  4.41229185e+00,
#         4.54563050e+00,  4.66820167e+00,  4.77733025e+00,  4.87034110e+00,
#         4.94455909e+00,  4.99730911e+00,  5.02591602e+00,  5.02770469e+00,
#         5.00000000e+00,  4.94111025e+00,  4.85327742e+00,  4.73972695e+00,
#         4.60368424e+00,  4.44837472e+00,  4.27702382e+00,  4.09285694e+00,
#         3.89909951e+00,  3.69897694e+00,  3.49571467e+00,  3.29253810e+00,
#         3.09267265e+00,  2.89934375e+00,  2.71577682e+00,  2.54519727e+00,
#         2.39083053e+00,  2.25590201e+00,  2.14363714e+00,  2.05726133e+00,
#         2.00000000e+00,  1.97358658e+00,  1.97378651e+00,  1.99487324e+00,
#         2.03112022e+00,  2.07680090e+00,  2.12618873e+00,  2.17355715e+00,
#         2.21317962e+00,  2.23932957e+00,  2.24628047e+00,  2.22830576e+00,
#         2.17967889e+00,  2.09467331e+00,  1.96756247e+00,  1.79261981e+00,
#         1.56411878e+00,  1.27633284e+00,  9.23535429e-01,  5.00000000e-01,
#         0.00000000e+00, -5.82191122e-01, -1.25229992e+00, -2.01605294e+00,
#        -2.87917673e+00, -3.84739785e+00, -4.92644285e+00, -6.12203828e+00,
#        -7.43991069e+00, -8.88578663e+00, -1.04653926e+01, -1.21844553e+01,
#        -1.40487011e+01, -1.60638567e+01, -1.82356486e+01, -2.05698033e+01,
#        -2.30720474e+01, -2.57481074e+01, -2.86037100e+01, -3.16445815e+01,
#        -3.48764487e+01])
